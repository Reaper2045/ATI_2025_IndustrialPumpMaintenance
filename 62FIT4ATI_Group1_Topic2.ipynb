# %% [markdown]
# ## PROJECT 2: INDUSTRIAL PUMP PREDICTIVE MAINTENANCE
#
# ### Goal
# Build a **time-series classification** model that predicts the operational status of an industrial pump based on multivariate sensor readings.
# ### Task
# Given a sequence (window) of sensor data, predict one of three classes:
# - **NORMAL**
# - **BROKEN**
# - **RECOVERING**
# ### Dataset
# - ~220k time steps (rows)
# - 52 sensor features (`sensor_0` ... `sensor_51`)
# - Target label: `machine_status`
# - Key challenge: extreme class imbalance (NORMAL dominates)
# - **Dataset link:** https://drive.google.com/drive/folders/1nUq198QcmosKNqOQOpheutsdcQTa67VF?usp=share_link
# ### Model
# We use an LSTM (Long Short-Term Memory) network because it can learn temporal patterns and longer dependencies in sequential sensor signals.

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ### Why predictive maintenance?
# Industrial pumps are critical equipment. Predicting failures early can reduce downtime, cost, and safety risk.
#
# ### What we predict
# We predict the current pump state (**NORMAL / BROKEN / RECOVERING**) using recent sensor history.
#
# ### Main challenges
# 1. **High-dimensional signals:** 52 sensors per timestamp
# 2. **Imbalanced classes:** BROKEN and RECOVERING are rare but important
# 3. **Temporal dependencies:** abnormal states may appear as patterns over time (not a single row)
#
# ### Workflow in this notebook
# 1. Load and inspect data
# 2. Clean and validate sensor values
# 3. Encode labels and scale features
# 4. Prepare sequences for LSTM (later sections)
# 5. Train + evaluate with imbalance-aware metrics
# 6. Inference demo on new sensor window

# %% [markdown]
# # 2. Environment Setup

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import sys, platform

import sklearn
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    balanced_accuracy_score,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# We fix random seeds to improve reproducibility.
# Training speed may differ depending on whether a GPU is available.

# %%
np.random.seed(42)
tf.random.set_seed(42)

tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("TensorFlow:", tf.__version__)
# Out:
# Python: 3.13.7
# Platform: Windows-11-10.0.26100-SP0
# NumPy: 2.3.5
# Pandas: 2.3.3
# Scikit-learn: 1.8.0
# TensorFlow: 2.20.0

# %%
# Global constants
LABEL_COL = 'machine_status'
TIMESTAMP_COL = 'timestamp'

# %%
# utility functions

def get_sensor_columns(df):
    return [col for col in df.columns if col.startswith('sensor_')]

# sliding window funtion
def create_sequences(X, y, window_size):
    X_seq, y_seq = [], []
    for i in range(len(X) - window_size):
        X_seq.append(X[i:i+window_size])
        y_seq.append(y[i+window_size])
    return np.array(X_seq), np.array(y_seq)

# %% [markdown]
# # 3. Load & Data inspection

# %% [markdown]
# ## 3.1. Initial data loading & inspection

# %% [markdown]
# We verify:
# - dataset shape and columns
# - label column and class distribution
# - missing values and basic sensor statistics
# - timestamp integrity (existence, ordering, duplicates)

# %%
DATA_PATH = "sensor.csv"
df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
print("Columns:", df.columns[:10].tolist(), "...", "Total:", len(df.columns))
df.head()
# Out:
# Shape: (220320, 55)
# Columns: ['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07'] ... Total: 55
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# ...

# %%
df.info()

# quick numeric summary for first few sensors (after we identify them later we will do deeper)
df.describe(include="all").T.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      220320 non-null  int64
#  1   timestamp       220320 non-null  object
#  2   sensor_00       210112 non-null  float64
#  3   sensor_01       219951 non-null  float64
#  4   sensor_02       220301 non-null  float64
#  5   sensor_03       220301 non-null  float64
#  6   sensor_04       220301 non-null  float64
#  7   sensor_05       220301 non-null  float64
#  8   sensor_06       215522 non-null  float64
#  9   sensor_07       214869 non-null  float64
#  10  sensor_08       215213 non-null  float64
#  11  sensor_09       215725 non-null  float64
#  12  sensor_10       220301 non-null  float64
#  13  sensor_11       220301 non-null  float64
#  14  sensor_12       220301 non-null  float64
#  15  sensor_13       220301 non-null  float64
# ...

# %%
df[LABEL_COL].value_counts()
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# sensor_15    220320
# sensor_50     77017
# sensor_51     15383
# sensor_00     10208
# sensor_07      5451
# sensor_08      5107
# sensor_06      4798
# sensor_09      4595
# sensor_01       369
# sensor_30       261
# dtype: int64

# %% [markdown]
# ### Timestamp integrity check
#
# LSTM requires correctly ordered time-series. We verify that timestamps exist, can be parsed, and are monotonic after sorting.

# %%
# Basic timestamp checks
if TIMESTAMP_COL in df.columns:
    ts = pd.to_datetime(df[TIMESTAMP_COL], errors="coerce")
    print("Timestamp parse NaT count:", ts.isna().sum())
    print("Duplicate timestamps:", ts.duplicated().sum())
    print("Min timestamp:", ts.min())
    print("Max timestamp:", ts.max())

    # visualize timestamp gaps roughly (sorted)
    ts_sorted = ts.sort_values()
    deltas = ts_sorted.diff().dropna().dt.total_seconds()

    plt.figure(figsize=(6,4))
    plt.hist(deltas, bins=50)
    plt.title("Histogram of time gaps (seconds) between consecutive timestamps")
    plt.xlabel("Gap (seconds)")
    plt.ylabel("Count")
    plt.show()
else:
    print("No timestamp column found:", TIMESTAMP_COL)
# Out:
# Timestamp parse NaT count: 0
# Duplicate timestamps: 0
# Min timestamp: 2018-04-01 00:00:00
# Max timestamp: 2018-08-31 23:59:00

# %% [markdown]
# ## 3.2. Target label distribution (class imbalance)
#
# Here we inspect the class distribution of `machine_status` to confirm the
# extreme class imbalance described in the project specification.

# %%
label_counts = df[LABEL_COL].value_counts().sort_values(ascending=False)
print(label_counts)

plt.figure(figsize=(5, 4))
sns.barplot(x=label_counts.index, y=label_counts.values)
plt.title("Class distribution of machine_status")
plt.ylabel("Number of samples")
plt.xlabel("Class label")
plt.show()
# Out:
# machine_status
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: count, dtype: int64

# %% [markdown]
# If the model predicts **NORMAL** most of the time, accuracy can look high but the model may still fail to detect **BROKEN**.
# Therefore later we evaluate using **balanced accuracy** and **macro F1-score** in addition to accuracy.

# %% [markdown]
# # 4. Data cleaning

# %% [markdown]
# ## 4.1. Drop non-informative columns

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ## 4.2 Timestamp processing

# %%
df[TIMESTAMP_COL] = pd.to_datetime(df[TIMESTAMP_COL])
df = df.sort_values(TIMESTAMP_COL).reset_index(drop=True)
# LSTM assumes ordered sequences — unsorted timestamps silently break models.

# %% [markdown]
# ## 4.3. Identify sensor columns

# %%
sensor_columns = get_sensor_columns(df)
len(sensor_columns)   # Expected: 52
# Out:
# 52

# %% [markdown]
# ## 4.4. Missing value handling

# %% [markdown]
# We visualize missingness and then fill using forward-fill and backward-fill.
# This preserves continuity in time-series signals and avoids dropping many rows.

# %%
sensor_columns = get_sensor_columns(df)

missing_rate = (df[sensor_columns].isna().mean().sort_values(ascending=False) * 100)
print("Top sensors by missing %:")
display(missing_rate.head(10))

plt.figure(figsize=(7,4))
plt.hist(missing_rate.values, bins=30)
plt.title("Distribution of missing percentage across sensors")
plt.xlabel("Missing %")
plt.ylabel("Number of sensors")
plt.show()
# Out:
# Top sensors by missing %:
# sensor_15    100.000000
# sensor_50     34.956881
# sensor_51      6.982117
# sensor_00      4.633261
# sensor_07      2.474129
# sensor_08      2.317992
# sensor_06      2.177741
# sensor_09      2.085603
# sensor_01      0.167484
# sensor_30      0.118464
# dtype: float64

# %%
df[sensor_columns] = df[sensor_columns].ffill().bfill()

# %% [markdown]
# ## 4.5. Numeric validation

# %%
df[sensor_columns] = df[sensor_columns].apply(
    pd.to_numeric, errors='coerce'
)

df[sensor_columns] = df[sensor_columns].ffill().bfill()

# %% [markdown]
# ## 4.6. Remove constant sensors

# %% [markdown]
# Sensors with only one unique value provide no predictive signal and may confuse the model.
# We detect and remove these constant sensors.

# %%
unique_counts = df[sensor_columns].nunique().sort_values()
display(unique_counts.head(10))

plt.figure(figsize=(7,4))
plt.hist(unique_counts.values, bins=30)
plt.title("Distribution of unique value counts across sensors")
plt.xlabel("Number of unique values")
plt.ylabel("Number of sensors")
plt.show()
# Out:
# sensor_15      0
# sensor_07    531
# sensor_09    565
# sensor_03    588
# sensor_41    594
# sensor_38    602
# sensor_47    621
# sensor_08    626
# sensor_44    628
# sensor_45    675
# dtype: int64

# %%
constant_sensors = [
    col for col in sensor_columns
    if df[col].nunique() <= 1
]

df.drop(columns=constant_sensors, inplace=True)
print(f"Removed {len(constant_sensors)} constant sensor(s)")
# Out:
# Removed 1 constant sensor(s)

# %% [markdown]
# ## 4.7 Final sanity check

# %%
assert df.isnull().sum().sum() == 0
print("Cleaned shape:", df.shape)
# Out:
# Cleaned shape: (220320, 53)

# %% [markdown]
# ### Quick sensor sanity visualization
#
# We plot a short segment of a few sensors to confirm values look continuous and reasonable after cleaning.

# %%
sample_sensors = sensor_columns[:3]
n = min(1000, len(df))

plt.figure(figsize=(10,4))
for col in sample_sensors:
    plt.plot(df[col].iloc[:n].values, label=col)
plt.title("Example sensor signals (first 1000 timesteps)")
plt.xlabel("Time index")
plt.ylabel("Sensor value")
plt.legend()
plt.show()

# %% [markdown]
# # 5. Label encoding

# %%
le = LabelEncoder()
df["label_encoded"] = le.fit_transform(df[LABEL_COL])

label_mapping = {cls: int(code) for cls, code in zip(le.classes_, le.transform(le.classes_))}
print("Label mapping:", label_mapping)

# distribution check
encoded_counts = df["label_encoded"].value_counts().sort_index()
print("\nEncoded label distribution:")
display(encoded_counts)

plt.figure(figsize=(5,4))
sns.barplot(x=[le.inverse_transform([i])[0] for i in encoded_counts.index],
            y=encoded_counts.values)
plt.title("Label distribution after encoding")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# Label mapping: {'BROKEN': 0, 'NORMAL': 1, 'RECOVERING': 2}
#
# Encoded label distribution:
# label_encoded
# 0         7
# 1    205836
# 2     14477
# Name: count, dtype: int64

# %% [markdown]
# # 6. Feature scaling

# %% [markdown]
# Neural networks train more stably when input features are on similar scales.
# We standardize sensor features using **StandardScaler** (zero mean, unit variance) fitted on the dataset at this stage.
#
# To confirm scaling worked, we compare:
# - summary statistics (mean/std) before vs after
# - distribution of a few example sensors

# %%
sensor_columns = get_sensor_columns(df)

# --- Before scaling: quick stats on a few sensors
check_cols = sensor_columns[:3]
before_stats = df[check_cols].agg(["mean","std","min","max"]).T
print("Before scaling (sample sensors):")
display(before_stats)

# --- Fit scaler and transform
scaler = StandardScaler()
df[sensor_columns] = scaler.fit_transform(df[sensor_columns])

# --- After scaling: quick stats
after_stats = df[check_cols].agg(["mean","std","min","max"]).T
print("After scaling (sample sensors):")
display(after_stats)

# --- Visualize distributions before/after for 1 sensor (approx by using stored before values)
# (We recreate 'before' by inverse transforming that one column slice for visualization)
col0 = check_cols[0]
scaled_vals = df[col0].values[:5000]

plt.figure(figsize=(6,4))
plt.hist(scaled_vals, bins=50)
plt.title(f"Distribution after scaling: {col0} (first 5000)")
plt.xlabel("Scaled value")
plt.ylabel("Count")
plt.show()
# Out:
# Before scaling (sample sensors):
#                 mean       std       min        max
# sensor_00   2.281158  0.585413   0.00000   2.549016
# sensor_01  47.597254  3.302558   0.00000  56.727430
# sensor_02  50.867093  3.667314  33.15972  56.032990
# After scaling (sample sensors):
#                    mean       std        min       max
# sensor_00  3.302450e-17  1.000002  -3.896670  0.457555
# sensor_01  1.981470e-16  1.000002 -14.412272  2.764583
# sensor_02 -1.469590e-15  1.000002  -4.828443  1.408636

# %% [markdown]
# # 7. Sequence generation for LSTM

# %% [markdown]
# LSTM models do not operate on individual rows; instead, they learn from
# **sequences of observations over time**.
#
# We therefore convert the raw time-series into overlapping sliding windows.
#
# ### Windowing strategy
# - Each input sample consists of `WINDOW_SIZE` consecutive timesteps
# - Each timestep contains all sensor features
# - The label for a sequence is the **machine status at the final timestep**
#
# ### Shapes
# - Input `X`: `(num_sequences, WINDOW_SIZE, num_features)`
# - Target `y`: `(num_sequences,)`
#
# This formulation allows the model to learn temporal patterns that precede
# changes in machine state.

# %%
WINDOW_SIZE = 50

X = df[sensor_columns].values
y = df['label_encoded'].values

X_seq, y_seq = create_sequences(X, y, WINDOW_SIZE)

X_seq.shape, y_seq.shape
# Out:
# ((220270, 50, 51), (220270,))

# %% [markdown]
# ### Sanity check: one generated sequence
#
# We inspect a single sequence to confirm that:
# - Values are continuous
# - The window length is correct
# - The label corresponds to the final timestep

# %%
print("X_seq shape:", X_seq.shape)
print("y_seq shape:", y_seq.shape)

seq_idx = 0

print("Sequence label (encoded):", y_seq[seq_idx])
print("Sequence label (decoded):", le.inverse_transform([y_seq[seq_idx]])[0])

plt.figure(figsize=(8,4))
for i in range(min(3, X_seq.shape[2])):
    plt.plot(X_seq[seq_idx, :, i], label=f"feature_{i}")

plt.title("Example sequence (first 3 features)")
plt.xlabel("Timestep")
plt.ylabel("Scaled value")
plt.legend()
plt.show()
# Out:
# X_seq shape: (220270, 50, 51)
# y_seq shape: (220270,)
# Sequence label (encoded): 1
# Sequence label (decoded): NORMAL

# %% [markdown]
# # 8. Train, validation, test split

# %% [markdown]
# Because this is a time-series problem, we must **preserve temporal order**
# when splitting the data. Random shuffling would cause information leakage
# from future samples into the past.
#
# ### Strategy
# - Split the sequences sequentially:
#   - Training set: earliest samples
#   - Validation set: middle segment
#   - Test set: most recent samples
#
# This setup simulates real-world deployment, where the model is trained on
# past data and evaluated on future, unseen behavior.

# %%
train_end = int(0.7 * len(X_seq))
val_end = int(0.85 * len(X_seq))

X_train, X_val, X_test = (
    X_seq[:train_end],
    X_seq[train_end:val_end],
    X_seq[val_end:]
)

y_train, y_val, y_test = (
    y_seq[:train_end],
    y_seq[train_end:val_end],
    y_seq[val_end:]
)

# %%
print("Train set:", X_train.shape, y_train.shape)
print("Validation set:", X_val.shape, y_val.shape)
print("Test set:", X_test.shape, y_test.shape)

assert (X_train.shape[0]+ X_val.shape[0]+ X_test.shape[0]== X_seq.shape[0])
# Out:
# Train set: (154189, 50, 51) (154189,)
# Validation set: (33040, 50, 51) (33040,)
# Test set: (33041, 50, 51) (33041,)

# %%
print("Train last label:", le.inverse_transform([y_train[-1]])[0])
print("Test first label:", le.inverse_transform([y_test[0]])[0])
# Out:
# Train last label: NORMAL
# Test first label: NORMAL

# %% [markdown]
# ## 8.1. Handling class imbalance with class-weighted loss

# %% [markdown]
# Because most samples belong to the NORMAL class, we compute class weights
# from the training set and use them in the loss function. This penalizes
# mistakes on minority classes (BROKEN, RECOVERING) more heavily and helps
# the model pay attention to rare but critical failures.

# %%
# Compute class weights on the training labels (sequence level)
unique_classes = np.unique(y_train)
class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=unique_classes,
    y=y_train
)

class_weights = {
    int(cls): float(weight)
    for cls, weight in zip(unique_classes, class_weights_array)
}

print("Class weights:", class_weights)
# Out:
# Class weights: {0: 8566.055555555555, 1: 0.3676918417619944, 2: 3.5686941628477524}

# %% [markdown]
# # 9. LSTM model architecture

# %% [markdown]
# We use a **stacked LSTM architecture** to model temporal dependencies in
# sensor data.
#
# ### Design choices
# - **LSTM layers:** capture long-term temporal patterns and handle vanishing
#   gradients better than vanilla RNNs
# - **Stacked structure:** deeper temporal abstraction
# - **Dropout:** regularization to reduce overfitting
# - **Softmax output:** multi-class classification (NORMAL / BROKEN / RECOVERING)

# %%
model = Sequential([
    Input(shape=(WINDOW_SIZE, X_train.shape[2])),

    LSTM(64, return_sequences=True),
    Dropout(0.3),

    LSTM(32),
    Dropout(0.3),

    Dense(len(le.classes_), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 50, 64)         │        29,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 50, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# ...

# %% [markdown]
# # 10. Model training

# %% [markdown]
# Training recurrent neural networks on imbalanced time-series data is
# challenging. We apply several optimization techniques to improve both
# **training stability** and **minority-class performance**.
#
# ### Techniques used
# 1. **Class-weighted loss**
#    - Penalizes mistakes on rare classes (BROKEN, RECOVERING) more heavily
#    - Mitigates bias toward the dominant NORMAL class
#
# 2. **Early stopping**
#    - Stops training when validation loss stops improving
#    - Prevents overfitting and keeps the best model weights
#
# 3. **Learning-rate scheduling (ReduceLROnPlateau)**
#    - Reduces learning rate when validation loss plateaus
#    - Allows finer convergence near an optimum
#
# 4. **Dropout regularization**
#    - Reduces co-adaptation of neurons
#    - Improves generalization

# %% [markdown]
# ## 10.1. Optimization settings (training stability)
#
# We use two optimization techniques to stabilize training:
#
# 1. **Early stopping** on validation loss to prevent overfitting and stop
#    when the model stops improving.
# 2. **ReduceLROnPlateau** to automatically decrease the learning rate when
#    validation loss plateaus, helping the optimizer make finer updates.

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    min_delta=1e-4,
    restore_best_weights=True,
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

# %% [markdown]
# ## 10.2. Training

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=64,
    callbacks=[early_stop, lr_scheduler],
    class_weight=class_weights
)
# Out:
# Epoch 1/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 61s 22ms/step - accuracy: 0.9293 - loss: 1.2407 - val_accuracy: 0.9836 - val_loss: 0.1826 - learning_rate: 0.0010
# Epoch 2/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 47s 19ms/step - accuracy: 0.8659 - loss: 0.7095 - val_accuracy: 0.9821 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 3/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 47s 20ms/step - accuracy: 0.9286 - loss: 0.4359 - val_accuracy: 0.9748 - val_loss: 0.0897 - learning_rate: 0.0010
# Epoch 4/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 49s 20ms/step - accuracy: 0.9441 - loss: 0.4049 - val_accuracy: 0.9269 - val_loss: 0.1991 - learning_rate: 0.0010
# Epoch 5/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 50s 21ms/step - accuracy: 0.9307 - loss: 0.5155 - val_accuracy: 0.9799 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 6/50
# 2410/2410 ━━━━━━━━━━━━━━━━━━━━ 51s 21ms/step - accuracy: 0.9000 - loss: 0.5124 - val_accuracy: 0.9857 - val_loss: 0.0469 - learning_rate: 0.0010
# Epoch 7/50
# ...

# %% [markdown]
# # 11. Model evaluation

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9869 - loss: 0.0321
# Test Accuracy: 0.9869

# %% [markdown]
# ## 11.1. Training curves (loss and accuracy)
#
# We visualize the training and validation loss/accuracy over epochs to check
# for overfitting and the effect of our optimization techniques.

# %%
# Plot training & validation loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training & validation accuracy
if 'accuracy' in history.history and 'val_accuracy' in history.history:
    plt.figure(figsize=(6, 4))
    plt.plot(history.history['accuracy'], label='Train accuracy')
    plt.plot(history.history['val_accuracy'], label='Val accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("Accuracy metric not found in history. Make sure you compiled the model with metrics=['accuracy'].")

# %% [markdown]
# ### Training behavior analysis
#
# The training and validation curves show that:
# - Early stopping prevents overfitting
# - Learning-rate reduction helps stabilize late-stage training
# - Validation performance improves without divergence from training loss

# %% [markdown]
# ## 11.2. Classification report

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)

labels = np.unique(np.concatenate([y_test, y_pred]))

print(
    classification_report(
        y_test,
        y_pred,
        labels=labels,
        target_names=le.inverse_transform(labels),
        zero_division=0
    )
)
# Out:
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
#               precision    recall  f1-score   support
#
#       BROKEN       0.00      0.00      0.00         0
#       NORMAL       1.00      0.99      0.99     33041
#
#     accuracy                           0.99     33041
#    macro avg       0.50      0.49      0.50     33041
# weighted avg       1.00      0.99      0.99     33041

# %% [markdown]
# ## 11.3. Imbalanced metrics: balanced accuracy and macro F1

# %% [markdown]
# Accuracy alone can be misleading under extreme class imbalance, because
# the model can be “right” most of the time just by predicting NORMAL.
# Balanced accuracy and macro F1 give equal importance to each class.

# %%
balanced_acc = balanced_accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average='macro')

print(f"Balanced accuracy: {balanced_acc:.4f}")
print(f"Macro F1-score:   {macro_f1:.4f}")
# Out:
# Balanced accuracy: 0.9869
# Macro F1-score:   0.4967
# F:\HANU\Fourth_year\ATI\Final\Final-project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2924: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")

# %% [markdown]
# ## 11.4. Confusion matrix

# %%
labels = np.unique(np.concatenate([y_test, y_pred]))
class_names = le.inverse_transform(labels)

cm = confusion_matrix(y_test, y_pred, labels=labels)

sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
# Out:
# <Axes: >

# %% [markdown]
# # 12. Inference on new data

# %% [markdown]
# In a real predictive maintenance system, we would receive a recent window
# of sensor readings and need to predict the current machine status. This
# section demonstrates how to run inference on a single window and interpret
# the output.

# %%
def predict_status_from_sequence(sequence, model, label_encoder):
    """
    sequence: np.array of shape (WINDOW_SIZE, num_features)
    returns: predicted label (string) and class probabilities
    """
    sequence = np.expand_dims(sequence, axis=0)  # (1, window, features)
    probs = model.predict(sequence)[0]
    pred_idx = np.argmax(probs)
    pred_label = label_encoder.inverse_transform([pred_idx])[0]
    return pred_label, probs

# Example: use the first test sequence as a stand-in for new data
sample_idx = 0
pred_label, probs = predict_status_from_sequence(
    X_test[sample_idx],
    model,
    le
)

true_label = le.inverse_transform([y_test[sample_idx]])[0]

print("Predicted status:", pred_label)
print("True status     :", true_label)
print("\nClass probabilities:")
for cls, p in zip(le.classes_, probs):
    print(f"  {cls:10s}: {p:.3f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Predicted status: NORMAL
# True status     : NORMAL
#
# Class probabilities:
#   BROKEN    : 0.000
#   NORMAL    : 1.000
#   RECOVERING: 0.000

# %%
# save trained model
model.save("trained_model.keras")

# %% [markdown]
# # 13. Conclusion
#
# In this project, we built an LSTM-based predictive maintenance model for
# industrial pumps using multivariate time-series sensor data.
#
# **Key points:**
#
# - **Problem & data:** The task was to classify the pump state
#   (NORMAL / BROKEN / RECOVERING) from 52 sensor channels over time. The
#   dataset is highly imbalanced, with NORMAL dominating.
#
# - **Model:** We implemented a stacked LSTM network with dropout for
#   regularization, trained on sliding windows of sensor readings.
#
# - **Optimization techniques:**
#   - We used **class-weighted loss** to reduce bias toward the majority
#     NORMAL class.
#   - We applied **early stopping** to prevent overfitting and keep the best
#     validation weights.
#   - We used **ReduceLROnPlateau** to automatically lower the learning rate
#     when validation loss stopped improving, improving training stability.
#
# - **Evaluation:** Besides accuracy, we reported **balanced accuracy** and
#   **macro F1-score**, and analyzed the confusion matrix to understand how
#   well the model detects BROKEN and RECOVERING states.
#
# - **Limitations & future work:** Performance on minority classes is still
#   constrained by the extreme imbalance and noise in sensor signals.
#   Future improvements could include more advanced resampling, focal loss,
#   or architectures like bidirectional LSTMs or GRUs, as well as additional
#   domain-specific feature engineering.
#
# Overall, the model demonstrates that LSTM-based sequence modeling with
# proper optimization and imbalance handling can provide a useful signal for
# predictive maintenance of industrial pumps.
